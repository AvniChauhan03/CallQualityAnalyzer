# %% [markdown]
# <a href="https://colab.research.google.com/github/AvniChauhan03/CallQualityAnalyzer/blob/main/CallQualityAnalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip -q install yt-dlp youtube-transcript-api webrtcvad python_speech_features nltk openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.0/485.0 kB 25.8 MB/s eta 0:00:00
#   Building wheel for webrtcvad (setup.py) ... done
#   Building wheel for python_speech_features (setup.py) ... done

# %%
# !pip install python_speech_features
# Out:
# Requirement already satisfied: python_speech_features in /usr/local/lib/python3.12/dist-packages (0.6)

# %%
from pydub import AudioSegment

# put your downloaded file here
video_file = "Sales Call example 1.mp4"
wav_file = "audio_16k.wav"

# it Converts to WAV, 16kHz, mono
audio = AudioSegment.from_file(video_file)
audio = audio.set_frame_rate(16000).set_channels(1)
audio.export(wav_file, format="wav")

print("Audio saved as:", wav_file)
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Audio saved as: audio_16k.wav

# %%
import numpy as np
from pydub import AudioSegment
from dataclasses import dataclass
from sklearn.cluster import KMeans
import wave
import contextlib
import webrtcvad

@dataclass
class Segment:
    start: float
    end: float
    speaker: int

def diarize(wavfile: str, n_speakers: int = 2):
    vad = webrtcvad.Vad(2)
    with contextlib.closing(wave.open(wavfile,'rb')) as wf:
        sample_rate = wf.getframerate()
        pcm = np.frombuffer(wf.readframes(wf.getnframes()), dtype=np.int16)

    window_size = int(0.03 * sample_rate)
    hop = int(0.01 * sample_rate)
    windows = [pcm[i:i+window_size].tobytes() for i in range(0, len(pcm)-window_size, hop)]
    voiced = [vad.is_speech(w, sample_rate) for w in windows]
    times = [i*hop/sample_rate for i in range(len(voiced))]

    labels = KMeans(n_clusters=n_speakers, random_state=0).fit_predict(np.array(voiced).reshape(-1,1))

    segs, cur, start = [], labels[0], times[0]
    for t, lab in zip(times, labels):
        if lab != cur:
            segs.append(Segment(start=start, end=t, speaker=int(cur)))
            cur, start = lab, t
    segs.append(Segment(start=start, end=times[-1]+0.5, speaker=int(cur)))
    return segs

def analyze_audio(wavfile: str):
    segs = diarize(wavfile)
    if not segs: return {}

    # calculate Talk-time %
    talk_time = {}
    for s in segs:
        talk_time[s.speaker] = talk_time.get(s.speaker,0) + (s.end - s.start)
    total = sum(talk_time.values())
    talk_ratio = {spk: round(100*t/total,1) for spk,t in talk_time.items()}

    # it finds out Longest monologue
    longest = max((s.end-s.start for s in segs))

    # it finds out approximate questions per speaker: short segments <1.5s
    questions = {s.speaker:0 for s in segs}
    for s in segs:
        if s.end - s.start <= 1.5:
            questions[s.speaker] += 1

    # finds out approximate sentiment from the audio energy
    audio = AudioSegment.from_file(wavfile)
    samples = np.array(audio.get_array_of_samples())
    energy = np.mean(np.abs(samples))
    if energy > 1000: sentiment = "Positive"
    elif energy < 300: sentiment = "Negative"
    else: sentiment = "Neutral"

    # Actionable insight
    if max(talk_ratio.values()) > 80: insight = "Conversation dominated by one speaker"
    elif sum(questions.values()) < 3: insight = "Try asking more questions"
    else: insight = "Balanced conversation"

    # Roles approximation: speaker with more talk-time = Sales
    roles = {}
    spk_sorted = sorted(talk_time.items(), key=lambda x:x[1], reverse=True)
    roles[spk_sorted[0][0]] = "Sales Rep"
    roles[spk_sorted[1][0]] = "Customer" if len(spk_sorted)>1 else "Unknown"

    return {
        "Talk-time %": talk_ratio,
        "Questions per speaker": questions,
        "Longest monologue (s)": round(longest,1),
        "Call sentiment": sentiment,
        "Actionable insight": insight,
        "Roles": roles
    }

# Example usage
report = analyze_audio("audio_16k.wav")
print(report)
# Out:
# {'Talk-time %': {0: 16.1, 1: 83.9}, 'Questions per speaker': {0: 145, 1: 126}, 'Longest monologue (s)': 6.8, 'Call sentiment': 'Positive', 'Actionable insight': 'Conversation dominated by one speaker', 'Roles': {1: 'Sales Rep', 0: 'Customer'}}

# %%
segments = diarize("audio_16k.wav", n_speakers=2)

for s in segments:
    print(f"Speaker {s.speaker}: {round(s.start,1)}s → {round(s.end,1)}s")
# Out:
# Speaker 0: 0.0s → 6.8s
# Speaker 1: 6.8s → 9.8s
# Speaker 0: 9.8s → 9.8s
# Speaker 1: 9.8s → 10.1s
# Speaker 0: 10.1s → 10.4s
# Speaker 1: 10.4s → 10.7s
# Speaker 0: 10.7s → 10.7s
# Speaker 1: 10.7s → 11.1s
# Speaker 0: 11.1s → 11.2s
# Speaker 1: 11.2s → 11.2s
# Speaker 0: 11.2s → 11.2s
# Speaker 1: 11.2s → 13.0s
# Speaker 0: 13.0s → 13.5s
# Speaker 1: 13.5s → 14.8s
# Speaker 0: 14.8s → 14.9s
# Speaker 1: 14.9s → 15.2s
# Speaker 0: 15.2s → 15.2s
# Speaker 1: 15.2s → 18.2s
# Speaker 0: 18.2s → 18.3s
# Speaker 1: 18.3s → 19.1s
# Speaker 0: 19.1s → 19.1s
# Speaker 1: 19.1s → 20.3s
# Speaker 0: 20.3s → 20.5s
# Speaker 1: 20.5s → 20.6s
# Speaker 0: 20.6s → 20.6s
# Speaker 1: 20.6s → 21.4s
# Speaker 0: 21.4s → 21.5s
# Speaker 1: 21.5s → 21.9s
# Speaker 0: 21.9s → 21.9s
# Speaker 1: 21.9s → 23.1s
# Speaker 0: 23.1s → 23.1s
# Speaker 1: 23.1s → 23.9s
# Speaker 0: 23.9s → 24.0s
# Speaker 1: 24.0s → 25.6s
# Speaker 0: 25.6s → 25.6s
# Speaker 1: 25.6s → 26.4s
# Speaker 0: 26.4s → 26.6s
# Speaker 1: 26.6s → 30.4s
# Speaker 0: 30.4s → 30.5s
# Speaker 1: 30.5s → 30.6s
# Speaker 0: 30.6s → 30.8s
# Speaker 1: 30.8s → 31.8s
# Speaker 0: 31.8s → 31.8s
# Speaker 1: 31.8s → 32.3s
# Speaker 0: 32.3s → 32.3s
# Speaker 1: 32.3s → 32.8s
# Speaker 0: 32.8s → 32.8s
# Speaker 1: 32.8s → 32.9s
# Speaker 0: 32.9s → 32.9s
# Speaker 1: 32.9s → 33.1s
# Speaker 0: 33.1s → 33.1s
# Speaker 1: 33.1s → 33.7s
# Speaker 0: 33.7s → 33.7s
# Speaker 1: 33.7s → 34.5s
# Speaker 0: 34.5s → 34.5s
# Speaker 1: 34.5s → 35.7s
# Speaker 0: 35.7s → 35.7s
# Speaker 1: 35.7s → 36.2s
# Speaker 0: 36.2s → 36.2s
# Speaker 1: 36.2s → 36.4s
# Speaker 0: 36.4s → 36.4s
# Speaker 1: 36.4s → 38.3s
# Speaker 0: 38.3s → 38.5s
# Speaker 1: 38.5s → 38.7s
# Speaker 0: 38.7s → 38.7s
# Speaker 1: 38.7s → 40.6s
# Speaker 0: 40.6s → 40.8s
# Speaker 1: 40.8s → 40.9s
# Speaker 0: 40.9s → 41.0s
# Speaker 1: 41.0s → 41.1s
# Speaker 0: 41.1s → 41.2s
# Speaker 1: 41.2s → 41.5s
# Speaker 0: 41.5s → 41.6s
# Speaker 1: 41.6s → 41.7s
# Speaker 0: 41.7s → 41.7s
# Speaker 1: 41.7s → 42.2s
# Speaker 0: 42.2s → 42.2s
# Speaker 1: 42.2s → 44.4s
# Speaker 0: 44.4s → 44.5s
# Speaker 1: 44.5s → 44.7s
# Speaker 0: 44.7s → 44.7s
# Speaker 1: 44.7s → 44.9s
# Speaker 0: 44.9s → 44.9s
# Speaker 1: 44.9s → 45.0s
# Speaker 0: 45.0s → 45.0s
# Speaker 1: 45.0s → 45.2s
# Speaker 0: 45.2s → 45.3s
# Speaker 1: 45.3s → 45.3s
# Speaker 0: 45.3s → 45.4s
# Speaker 1: 45.4s → 45.9s
# Speaker 0: 45.9s → 45.9s
# Speaker 1: 45.9s → 46.6s
# Speaker 0: 46.6s → 46.6s
# Speaker 1: 46.6s → 47.8s
# Speaker 0: 47.8s → 47.8s
# Speaker 1: 47.8s → 49.8s
# Speaker 0: 49.8s → 49.8s
# Speaker 1: 49.8s → 50.3s
# Speaker 0: 50.3s → 50.3s
# Speaker 1: 50.3s → 50.6s
# Speaker 0: 50.6s → 50.7s
# Speaker 1: 50.7s → 51.1s
# Speaker 0: 51.1s → 51.1s
# Speaker 1: 51.1s → 51.7s
# Speaker 0: 51.7s → 51.7s
# Speaker 1: 51.7s → 53.5s
# Speaker 0: 53.5s → 53.5s
# Speaker 1: 53.5s → 53.6s
# Speaker 0: 53.6s → 53.7s
# Speaker 1: 53.7s → 53.9s
# Speaker 0: 53.9s → 53.9s
# Speaker 1: 53.9s → 54.2s
# Speaker 0: 54.2s → 54.3s
# Speaker 1: 54.3s → 58.3s
# Speaker 0: 58.3s → 58.3s
# Speaker 1: 58.3s → 58.3s
# Speaker 0: 58.3s → 58.5s
# Speaker 1: 58.5s → 58.6s
# Speaker 0: 58.6s → 58.6s
# Speaker 1: 58.6s → 59.8s
# Speaker 0: 59.8s → 59.8s
# Speaker 1: 59.8s → 60.3s
# Speaker 0: 60.3s → 60.4s
# Speaker 1: 60.4s → 62.5s
# Speaker 0: 62.5s → 62.5s
# Speaker 1: 62.5s → 62.7s
# Speaker 0: 62.7s → 62.7s
# Speaker 1: 62.7s → 64.2s
# Speaker 0: 64.2s → 64.2s
# Speaker 1: 64.2s → 64.5s
# Speaker 0: 64.5s → 64.7s
# Speaker 1: 64.7s → 64.8s
# Speaker 0: 64.8s → 64.8s
# Speaker 1: 64.8s → 65.5s
# Speaker 0: 65.5s → 65.5s
# Speaker 1: 65.5s → 66.6s
# Speaker 0: 66.6s → 66.6s
# Speaker 1: 66.6s → 66.7s
# Speaker 0: 66.7s → 66.7s
# Speaker 1: 66.7s → 66.8s
# Speaker 0: 66.8s → 67.0s
# Speaker 1: 67.0s → 67.3s
# Speaker 0: 67.3s → 67.4s
# Speaker 1: 67.4s → 67.9s
# Speaker 0: 67.9s → 68.0s
# Speaker 1: 68.0s → 68.9s
# Speaker 0: 68.9s → 69.0s
# Speaker 1: 69.0s → 69.1s
# Speaker 0: 69.1s → 69.1s
# Speaker 1: 69.1s → 69.5s
# Speaker 0: 69.5s → 69.6s
# Speaker 1: 69.6s → 69.7s
# Speaker 0: 69.7s → 69.7s
# Speaker 1: 69.7s → 71.6s
# Speaker 0: 71.6s → 71.7s
# Speaker 1: 71.7s → 72.5s
# Speaker 0: 72.5s → 72.5s
# Speaker 1: 72.5s → 73.3s
# Speaker 0: 73.3s → 73.3s
# Speaker 1: 73.3s → 74.7s
# Speaker 0: 74.7s → 74.7s
# Speaker 1: 74.7s → 75.3s
# Speaker 0: 75.3s → 75.7s
# Speaker 1: 75.7s → 78.7s
# Speaker 0: 78.7s → 79.0s
# Speaker 1: 79.0s → 79.1s
# Speaker 0: 79.1s → 79.2s
# Speaker 1: 79.2s → 79.3s
# Speaker 0: 79.3s → 79.4s
# Speaker 1: 79.4s → 81.0s
# Speaker 0: 81.0s → 81.0s
# Speaker 1: 81.0s → 81.1s
# Speaker 0: 81.1s → 81.1s
# Speaker 1: 81.1s → 81.2s
# Speaker 0: 81.2s → 81.3s
# Speaker 1: 81.3s → 81.8s
# Speaker 0: 81.8s → 81.8s
# Speaker 1: 81.8s → 82.1s
# Speaker 0: 82.1s → 82.1s
# Speaker 1: 82.1s → 82.9s
# Speaker 0: 82.9s → 83.0s
# Speaker 1: 83.0s → 83.0s
# Speaker 0: 83.0s → 83.0s
# Speaker 1: 83.0s → 84.6s
# Speaker 0: 84.6s → 84.6s
# Speaker 1: 84.6s → 85.5s
# Speaker 0: 85.5s → 85.5s
# Speaker 1: 85.5s → 85.7s
# Speaker 0: 85.7s → 85.7s
# Speaker 1: 85.7s → 85.9s
# Speaker 0: 85.9s → 85.9s
# Speaker 1: 85.9s → 87.1s
# Speaker 0: 87.1s → 87.1s
# Speaker 1: 87.1s → 87.6s
# Speaker 0: 87.6s → 87.6s
# Speaker 1: 87.6s → 88.1s
# Speaker 0: 88.1s → 88.1s
# Speaker 1: 88.1s → 89.8s
# Speaker 0: 89.8s → 89.8s
# Speaker 1: 89.8s → 90.0s
# Speaker 0: 90.0s → 90.0s
# Speaker 1: 90.0s → 90.3s
# Speaker 0: 90.3s → 90.4s
# Speaker 1: 90.4s → 90.6s
# Speaker 0: 90.6s → 90.6s
# Speaker 1: 90.6s → 90.8s
# Speaker 0: 90.8s → 90.8s
# Speaker 1: 90.8s → 91.1s
# Speaker 0: 91.1s → 91.1s
# Speaker 1: 91.1s → 91.2s
# Speaker 0: 91.2s → 91.2s
# Speaker 1: 91.2s → 92.3s
# Speaker 0: 92.3s → 92.4s
# Speaker 1: 92.4s → 92.7s
# Speaker 0: 92.7s → 92.7s
# Speaker 1: 92.7s → 93.1s
# Speaker 0: 93.1s → 93.1s
# Speaker 1: 93.1s → 93.7s
# Speaker 0: 93.7s → 93.7s
# Speaker 1: 93.7s → 94.1s
# Speaker 0: 94.1s → 94.1s
# Speaker 1: 94.1s → 94.2s
# Speaker 0: 94.2s → 94.2s
# Speaker 1: 94.2s → 94.5s
# Speaker 0: 94.5s → 94.5s
# Speaker 1: 94.5s → 94.9s
# Speaker 0: 94.9s → 94.9s
# Speaker 1: 94.9s → 95.0s
# Speaker 0: 95.0s → 95.2s
# Speaker 1: 95.2s → 95.4s
# Speaker 0: 95.4s → 95.4s
# Speaker 1: 95.4s → 96.2s
# Speaker 0: 96.2s → 96.3s
# Speaker 1: 96.3s → 97.4s
# Speaker 0: 97.4s → 97.4s
# Speaker 1: 97.4s → 97.6s
# Speaker 0: 97.6s → 97.7s
# Speaker 1: 97.7s → 99.7s
# Speaker 0: 99.7s → 99.7s
# Speaker 1: 99.7s → 99.9s
# Speaker 0: 99.9s → 100.0s
# Speaker 1: 100.0s → 100.0s
# Speaker 0: 100.0s → 100.0s
# Speaker 1: 100.0s → 100.8s
# Speaker 0: 100.8s → 100.8s
# Speaker 1: 100.8s → 100.9s
# Speaker 0: 100.9s → 100.9s
# Speaker 1: 100.9s → 101.3s
# Speaker 0: 101.3s → 101.4s
# Speaker 1: 101.4s → 101.5s
# Speaker 0: 101.5s → 101.5s
# Speaker 1: 101.5s → 102.4s
# Speaker 0: 102.4s → 102.4s
# Speaker 1: 102.4s → 104.2s
# Speaker 0: 104.2s → 104.5s
# Speaker 1: 104.5s → 104.8s
# Speaker 0: 104.8s → 104.8s
# Speaker 1: 104.8s → 105.0s
# Speaker 0: 105.0s → 105.1s
# Speaker 1: 105.1s → 105.2s
# Speaker 0: 105.2s → 105.2s
# Speaker 1: 105.2s → 105.8s
# Speaker 0: 105.8s → 105.8s
# Speaker 1: 105.8s → 107.1s
# Speaker 0: 107.1s → 107.2s
# Speaker 1: 107.2s → 107.8s
# Speaker 0: 107.8s → 108.0s
# Speaker 1: 108.0s → 108.2s
# Speaker 0: 108.2s → 108.2s
# Speaker 1: 108.2s → 108.6s
# Speaker 0: 108.6s → 108.7s
# Speaker 1: 108.7s → 109.4s
# Speaker 0: 109.4s → 109.7s
# Speaker 1: 109.7s → 110.7s
# Speaker 0: 110.7s → 110.7s
# Speaker 1: 110.7s → 112.6s
# Speaker 0: 112.6s → 112.7s
# Speaker 1: 112.7s → 113.3s
# Speaker 0: 113.3s → 113.3s
# Speaker 1: 113.3s → 114.7s
# Speaker 0: 114.7s → 114.9s
# Speaker 1: 114.9s → 115.4s
# Speaker 0: 115.4s → 115.4s
# Speaker 1: 115.4s → 115.4s
# Speaker 0: 115.4s → 115.5s
# Speaker 1: 115.5s → 116.6s
# Speaker 0: 116.6s → 116.6s
# Speaker 1: 116.6s → 116.9s
# Speaker 0: 116.9s → 117.0s
# Speaker 1: 117.0s → 118.2s
# Speaker 0: 118.2s → 118.2s
# Speaker 1: 118.2s → 118.4s
# Speaker 0: 118.4s → 123.2s

# %%
# Talk time per speaker
talk_time = {}
for s in segments:
    talk_time[s.speaker] = talk_time.get(s.speaker, 0) + (s.end - s.start)

total = sum(talk_time.values())
ratio = {spk: round(100 * t / total, 1) for spk, t in talk_time.items()}

# Longest monologue
longest = max(s.end - s.start for s in segments)

print("Talk-time % per speaker:", ratio)
print("Longest monologue (s):", round(longest,1))
# Out:
# Talk-time % per speaker: {0: 16.1, 1: 83.9}
# Longest monologue (s): 6.8

# %%
wav_file = "audio_16k.wav"
report = analyze_audio(wav_file)
print(report)
# Out:
# {'Talk-time %': {0: 16.1, 1: 83.9}, 'Questions per speaker': {0: 145, 1: 126}, 'Longest monologue (s)': 6.8, 'Call sentiment': 'Positive', 'Actionable insight': 'Conversation dominated by one speaker', 'Roles': {1: 'Sales Rep', 0: 'Customer'}}
